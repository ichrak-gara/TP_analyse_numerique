# %% [markdown]
#  # Compte Rendu TP1 Analyse Numérique

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# # Exercice 1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Question 1:

# %%
#importation
import matplotlib.pyplot as plt
import numpy as np


def horner(T,Z):
    n=len(T)
    result=T[0]
    for i in T[1:]:
        result=result*Z+i
    return result

T=[1,-6,15,-20,15,-6,1]
X=np.arange(0.998,1.002,0.001)
for i in X:
    print(horner(T,i))
# Out:
# -1.3322676295501878e-15
# -2.220446049250313e-15
# 0.0
# -6.661338147750939e-16
# -6.661338147750939e-16

# %% [markdown]
# ###### Question 2:

# %%
import numpy as np

intervalle=np.arange(0.998,1.002,0.0001)
print(intervalle)
# Out:
# [0.998  0.9981 0.9982 0.9983 0.9984 0.9985 0.9986 0.9987 0.9988 0.9989
#  0.999  0.9991 0.9992 0.9993 0.9994 0.9995 0.9996 0.9997 0.9998 0.9999
#  1.     1.0001 1.0002 1.0003 1.0004 1.0005 1.0006 1.0007 1.0008 1.0009
#  1.001  1.0011 1.0012 1.0013 1.0014 1.0015 1.0016 1.0017 1.0018 1.0019
#  1.002 ]

# %%
#Expression réduite
def p(x):
    return (x-1)**6

#expression developpée
def f(x):
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %% [markdown]
# #### représentation graphique:

# %%
plt.plot(X,f(X),'r',X,p(X),'b')
plt.xlabel('X')
plt.ylabel('f')
plt.title ("solution dans (0.998,1.002,0.001)")
plt.show()

# %% [markdown]
# ##  Explication:

# %% [markdown]
# On remarque qu'il y a une très grande différence entre la fonction p (x) et la fonction f (x) malgré c'est la même fonction.
# Lors de la séance tp, nous étions convaincus que l'ordinateur avait commis une erreur de codage, c'est-à-dire qu'il ne pouvait pas coder un nombre infini de chiffres après la virgule décimale, il deviendrait donc plus fiable si un grand nombre n'était pas encodé.
# Il est obligé donc faire les arandis, c'est pourquoi nous avons vu qu'il y a une différence de 100 chiffres après la virgule décimale.

# %% [markdown]
# # Exercice 2:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Question 1:

# %%
#importation
import matplotlib.pyplot as plt
from numpy import linspace

def g(x):
    return x**3+x**2-3*x-3

# %% [markdown]
# ### Représentation graphique:

# %%
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,(T))
plt.show()

# %% [markdown]
# ###### Question 2:

# %%
def dicho(f,a,b,tol):
    m=(a+b)/2
    err=abs(b-a)
    while err>tol :
        if f(m)==0 :
            break
   
        if f(a)*f(m)<0 :
            b=m
        else: a=m
    
        m=(a+b)/2
        err=abs(b-a)
    return m

# %%
print(dicho(g,-2,2,0.001))
# Out:
# 1.73193359375

# %%
def dichow(f,a,b,tol):
    m=(a+b)/2
    err=abs(b-a)
    i=0
    while err>tol :
        if f(m)==0 :
            break
   
        if f(a)*f(m)<0 :
            b=m
        else: a=m
    
        m=(a+b)/2
        err=abs(b-a)
        i=i+1
    return (m,i)

# %%
print(dichow(g,-2,-1.5,0.0001))
# Out:
# (-1.732025146484375, 13)

# %% [markdown]
# ###### Question 3:

# %%
#importation
import matplotlib.pyplot as plt
from numpy import linspace
import numpy as np 


t=linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
#######################
t=linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'g')
########################
t=linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'y')
###########################
t=linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'m')
plt.show()

# %%
import numpy as np
print(np.floor(2.3))
print(np.ceil(2.3))
# Out:
# 2.0
# 3.0

# %% [markdown]
# ### la fonction np.floor: Renvoie le plancher de l'entrée, élément par élément.
# ### la fonction np.ceil: Le ceil du scalaire x est le plus petit entier i , tel que i> = x.

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
print(dichow(f,a,b,(10**(-p))))
# Out:
# (-0.5000000037252903, 27)

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(dichow(f,u[0],u[1],10**(-3)))
########################################  
print(dichow(f,-2,-1.5,10**(-3)))
print(dichow(f,-1.5,-0.5,10**(-3)))
print(dichow(f,1.5,2,10**(-3)))
# Out:
# (-1.50048828125, 9)
# (-0.50048828125, 10)
# (1.99951171875, 9)
# (-1.50048828125, 9)
# (-0.50048828125, 10)
# (1.99951171875, 9)

# %% [markdown]
# ![log.PNG](attachment:log.PNG)

# %%
#importation:
from math import log
def ND(p):
    n=(((log(b-a)+p*log(10))/log(2))+1)
    return n

# %%
a=-2
b=-1.5
ND(5)
# Out:
# 16.609640474436816

# %%
#alpha 1
print(dichow(f,-2,-1.5,10**(-5)))
#à 10^-8
# Out:
# (-1.5000038146972656, 16)

# %%
#alpha 2
dichow(f,-1.51,-0.5,10**(-5))
#à 10^-8
# Out:
# (-0.5000038528442383, 17)

# %% [markdown]
# # Exercice 3:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Question 1:

# %%
#importation
import matplotlib.pyplot as plt
from numpy import linspace

def h(x):
    return x**3+4*x**2-10

# %% [markdown]
# ### Représentation graphique:

# %%
t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'y')
plt.grid(True)
###########################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'m')
plt.grid(True)
##############################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'g')
plt.grid(True)

# %% [markdown]
# ###### Question 2:

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)

# %%
def g1(x):
    return 1/2*sqrt(10-x**3)

g1=lambda x: 1/2*sqrt(10-x**3)
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# ### Que pouvez vous conclure à propos des convergences de g1:

# %% [markdown]
# Puisque la valeur de g1 est négatife et la valeur absolu de g1 |g1(x)| est inférieur à 1 donc la méthode de point fixe converge totalemen, c'est à dire, il exixteun locale I dans l'intervale [1,2].

# %% [markdown]
# ### Etude théorique de la convergences de g2 et g3:

# %% [markdown]
# ![etude_theorique.jpg](attachment:etude_theorique.jpg)

# %%
from math import sqrt

g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x: sqrt(10./(x+4))
g3=lambda x: x-x**3-4*x**2 + 10

# %%
def pointfixe(g,x0,eps,nmax):
    zero=x0
    for niter in range(0,nmax):
        x=zero
        zero=g1(x)
        erreur=abs(zero-x)
        if erreur<eps: 
            return x

# %%
print(pointfixe(g1,1.5,0.001,50))
# Out:
# 1.364878217193677

# %%
print(pointfixe(g2,1.5,0.001,50))
# Out:
# 1.364878217193677

# %%
print(pointfixe(g3,1.5,0.001,50))
# Out:
# 1.364878217193677

# %% [markdown]
# # Exercice 4:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Question 1:

# %%
def newton(a,eps):
    x1=a
    x2=x1-f(x1)/fprime(x1)
    
    while abs(x1-x2)>eps:
        x1=x2
        x2=x1-f(x1)/fprime(x1)
        sol=x2
    return sol

# %%
#importation
import matplotlib.pyplot as plt
from numpy import linspace
from math import exp, expm1
import numpy as np

# %%
def f(x):
    return exp(-x)-x

def fprime(x):
    return -exp(-x)-1

f2 = np.vectorize(f)
t=np.linspace(0,1,100)
plt.plot(t,f2(t),'y')
plt.show()

# %%
print(newton(0,0.001))
# Out:
# 0.5671431650348622

# %%
print(newton(1,0.001))
# Out:
# 0.567143285989123

# %% [markdown]
# ### conclusion:

# %% [markdown]
# Après les trois méthodes que nous avons déjà vues (Dichotomie,Point fixe et Newton), nous remarquons que la méthode de Newton est la plus rapide et la plus simple, ce qui nous donne un taux d'erreur très faible, tandis que la méthode de point fixe donne un taux d'erreur moyen et la dernière, qui est la méthode de dichotomie la plus lente qui est très lente et prend beaucoup de temps Pour les calculer en plus d'un grand nombre d'erreurs.
